# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
# r.text
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11121573988","type":"PushEvent","actor":{"id":38440346,"login":"NDNZaro","display_login":"NDNZaro","gravatar_id":"","url":"https://api.github.com/users/NDNZaro","avatar_url":"https://avatars.githubusercontent.com/u/38440346?"},"repo":{"id":228436467,"name":"NDNZaro/hacker-news-clone","url":"https://api.github.com/repos/NDNZaro/hacker-news-clone"},"payload":{"push_id":4414641429,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"2f7dfb520ff8435bdf446207780d9f77a7458c1a","before":"c39d21644683a4353de6f42f1b540af18cdf4075","commits":[{"sha":"2f7dfb520ff8435bdf446207780d9f77a7458c1a","author":{"email":"38440346+NDNZaro@users.noreply.github.com","name":"Aleksa Milovanovic"},"message":"Finished Top and New component","distinct":true,"url":"https://api.github.com/repos/NDNZaro/hacker-news-clone/commits/2f7dfb520ff8435bdf446207780d9f77a7458c1a"}]},"public":true,"created_at":"2019-12-19T00:34:01Z"},{"id":"11121573979","type":"PushEvent","actor":{"id":32518570,"login":"trphuongnam15","display_login":"trphuongnam15","gravatar_id":"","url":"https://api.github.com/users/trphuongnam15","avatar_url":"https://avatars.githubusercontent.com/u/32518570?"},"repo":{"id":222905514,"name":"trphuongnam15/web_project","url":"https://api.github.com/repos/trphuongnam15/web_project"},"payload":{"push_id":4414641424,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"7807e5a6af27f50345e00b05909d113a7c4d98ce","before":"679813a17b082fddcd73d4faae831748a7a7a864","commits":[{"sha":"7807e5a6af27f50345e00b05909d113a7c4d98ce","author":{"email":"trphuongnam15@outlook.com","name":"Trần Phương Nam"},"message":"Update admin_products.inc.php","distinct":true,"url":"https://api.github.com/repos/trphuongnam15/web_project/commits/7807e5a6af27f50345e00b05909d113a7c4d98ce"}]},"public":true,"created_at":"2019-12-19T00:34:01Z"},{"id":"11121573971","type":"PublicEvent","actor":{"id":10171839,"login":"vitalves","display_login":"vitalves","gravatar_id":"","url":"https://api.github.com/users/vitalves","avatar_url":"https://avatars.githubusercontent.com/u/10171839?"},"repo":{"id":228691328,"name":"vitalves/gobarber-backend","url":"https://api.github.com/repos/vitalves/gobarber-backend"},"payload":{},"public":true,"created_at":"2019-12-19T00:34:01Z"},{"id":"11121573967","type":"PushEvent","actor":{"id":57318610,"login":"Lusio7","display_login":"Lusio7","gravatar_id":"","url":"https://api.github.com/users/Lusio7","avatar_url":"https://avatars.githubusercontent.com/u/57318610?"},"repo":{"id":228939040,"name":"Lusio7/weather-app-hw6","url":"https://api.github.com/repos/Lusio7/weather-app-hw6"},"payload":{"push_id":4414641419,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"7c36975d250bfa99f78ce11fe85abe626b8f3bf9","before":"520761ddb9b032a271b0b157e6ea1ff3ab6a61e9","commits":[{"sha":"7c36975d250bfa99f78ce11fe85abe626b8f3bf9","author":{"email":"lusiof@gmail.com","name":"LusioF"},"message":"created new div with details for weather conditions and the icons that correspond","distinct":true,"url":"https://api.github.com/repos/Lusio7/weather-app-hw6/commits/7c36975d250bfa99f78ce11fe85abe626b8f3bf9"}]},"public":true,"created_at":"2019-12-19T00:34:01Z"},{"id":"11121573966","type":"PushEvent","actor":{"id":39018047,"login":"jbmi2000","display_login":"jbmi2000","gravatar_id":"","url":"https://api.github.com/users/jbmi2000","avatar_url":"https://avatars.githubusercontent.com/u/39018047?"},"repo":{"id":228936019,"name":"jbmi2000/deli-counter-onl01-seng-pt-120819","url":"https://api.github.com/repos/jbmi2000/deli-counter-onl01-seng-pt-120819"},"payload":{"push_id":4414641417,"size":1,"distinct_size":1,"ref":"refs/heads/wip","head":"958b873ca6af987e1620be5d68d34727834abc70","before":"0dd5fd984b3040165055ae563ec0282efd651205","commits":[{"sha":"958b873ca6af987e1620be5d68d34727834abc70","author":{"email":"jeff.marbury@gmail.com","name":"Jeffrey Marbury"},"message":"Automatically backed up by Learn","distinct":true,"url":"https://api.github.com/repos/jbmi2000/ ...

# %%
# json.loads(r.text)

import json
json.loads(r.text)
# Out:
# [{'id': '11121573988',
#   'type': 'PushEvent',
#   'actor': {'id': 38440346,
#    'login': 'NDNZaro',
#    'display_login': 'NDNZaro',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NDNZaro',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38440346?'},
#   'repo': {'id': 228436467,
#    'name': 'NDNZaro/hacker-news-clone',
#    'url': 'https://api.github.com/repos/NDNZaro/hacker-news-clone'},
#   'payload': {'push_id': 4414641429,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2f7dfb520ff8435bdf446207780d9f77a7458c1a',
#    'before': 'c39d21644683a4353de6f42f1b540af18cdf4075',
#    'commits': [{'sha': '2f7dfb520ff8435bdf446207780d9f77a7458c1a',
#      'author': {'email': '38440346+NDNZaro@users.noreply.github.com',
#       'name': 'Aleksa Milovanovic'},
#      'message': 'Finished Top and New component',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/NDNZaro/hacker-news-clone/commits/2f7dfb520ff8435bdf446207780d9f77a7458c1a'}]},
#   'public': True,
#   'created_at': '2019-12-19T00:34:01Z'},
#  {'id': '11121573979',
#   'type': 'PushEvent',
#   'actor': {'id': 32518570,
#    'login': 'trphuongnam15',
#    'display_login': 'trphuongnam15',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/trphuongnam15',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32518570?'},
#   'repo': {'id': 222905514,
#    'name': 'trphuongnam15/web_project',
#    'url': 'https://api.github.com/repos/trphuongnam15/web_project'},
#   'payload': {'push_id': 4414641424,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7807e5a6af27f50345e00b05909d113a7c4d98ce',
#    'before': '679813a17b082fddcd73d4faae831748a7a7a864',
#    'commits': [{'sha': '7807e5a6af27f50345e00b05909d113a7c4d98ce',
#      'author': {'email': 'trphuongnam15@outlook.com',
#       'name': 'Trần Phương Nam'},
#      'message': 'Update admin_products.inc.php',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/trphuongnam15/web_project/commits/7807e5a6af27f50345e00b05909d113a7c4d98ce'}]},
#   'public': True,
#   'created_at': '2019-12-19T00:34:01Z'},
#  {'id': '11121573971',
#   'type': 'PublicEvent',
#   'actor': {'id': 10171839,
#    'login': 'vitalves',
#    'display_login': 'vitalves',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vitalves',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10171839?'},
#   'repo': {'id': 228691328,
#    'name': 'vitalves/gobarber-backend',
#    'url': 'https://api.github.com/repos/vitalves/gobarber-backend'},
#   'payload': {},
#   'public': True,
#   'created_at': '2019-12-19T00:34:01Z'},
#  {'id': '11121573967',
#   'type': 'PushEvent',
#   'actor': {'id': 57318610,
#    'login': 'Lusio7',
#    'display_login': 'Lusio7',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Lusio7',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57318610?'},
#   'repo': {'id': 228939040,
#    'name': 'Lusio7/weather-app-hw6',
#    'url': 'https://api.github.com/repos/Lusio7/weather-app-hw6'},
#   'payload': {'push_id': 4414641419,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7c36975d250bfa99f78ce11fe85abe626b8f3bf9',
#    'before': '520761ddb9b032a271b0b157e6ea1ff3ab6a61e9',
#    'commits': [{'sha': '7c36975d250bfa99f78ce11fe85abe626b8f3bf9',
#      'author': {'email': 'lusiof@gmail.com', 'name': 'LusioF'},
#      'message': 'created new div with details for weather conditions and the icons that correspond',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Lusio7/weather-app-hw6/commits/7c36975d250bfa99f78ce11fe85abe626b8f3bf9'}]},
#   'public': True,
#   'created_at': '2019-12-19T00:34:01Z'},
#  {'id': '11121573966',
#   'type': 'PushEvent',
#   'actor': {'id': 39018047,
#    'login': 'jbmi2000',
#    'display_login': 'jbmi2000',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbmi2000',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39018047?'},
#   'repo': {'id': 228936019,
#    'name': 'jbmi2000/deli-counter-onl01-seng-pt-120819',
#    'url': 'https://api.github.com/repos/jbmi2000/deli-counter-onl01-seng-pt-120819'},
#   'payload': {'push_id': 4414641417,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': '958b873ca6af987e1620be5d68d34727834abc70',
#    'before': '0dd5fd984b3040165055ae563ec0282efd651205',
#    'commits': [{'sha': '958b873ca6af987e1620be5d68d34727834abc70',
#      'author': {'email': 'jeff.marbury@gmail.com', 'name': 'Jeffrey Marbury'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jbmi2000/deli-counter-onl01-seng-pt-120819/commits/958b873ca6af987e1620be5d68d34727834abc70'}]},
#   'public': True,
#   'created_at': '2019-12-19T00:34:01Z'},
#  {'id': '11121573968',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 347387,
#    'login': 'felipenmoura',
#    'display_login': 'felipenmoura',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/felipenmoura',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/347387?'},
#   'repo': {'id': 42488903,
#    'name': 'aframevr/aframe',
#    'url': 'https://api.github.com/repos/aframevr/aframe'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/aframevr/aframe/issues/4317',
#     'repository_url': 'https://api.github.com/repos/aframevr/aframe',
#     'labels_url': 'https://api.github.com/repos/aframevr/aframe/issues/4317/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/aframevr/aframe/issues/4317/comments',
#     'events_url': 'https://api.github.com/repos/aframevr/aframe/issues/4317/events',
#     'html_url': 'https://github.com/aframevr/aframe/issues/4317',
#     'id': 525026626,
#     'node_id': 'MDU6SXNzdWU1MjUwMjY2MjY=',
#     'number': 4317,
#     'title': 'Next stable Chrome (79) implementing WebXR Device API, will break aframe',
#     'user': {'login': 'nicolocarpignoli',
#      'id': 22395670,
#      'node_id': 'MDQ6VXNlcjIyMzk1Njcw',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/22395670?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/nicolocarpignoli',
#      'html_url': 'https://github.com/nicolocarpignoli',
#      'followers_url': 'https://api.github.com/users/nicolocarpignoli/followers',
#      'following_url': 'https://api.github.com/users/nicolocarpignoli/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/nicolocarpignoli/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/nicolocarpignoli/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/nicolocarpignoli/subscriptions',
#      'organizations_url': 'https://api.github.com/users/nicolocarpignoli/orgs',
#      'repos_url': 'https://api.github.com/users/nicolocarpignoli/repos',
#      'events_url': 'https://api.github.com/users/nicolocarpignoli/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/nicolocarpignoli/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 10,
#     'created_at': '2019-11-19T13:58:10Z',
#     'updated_at': '2019-12-19T00:34:01Z',
#     'closed_at': '2019-11-19T15:15:33Z',
#     'author_association': 'NONE',
#     'body': "**Description:**\r\n\r\n- A-Frame Version: 0.9.2\r\n- Platform / Device: Chrome 79 (you can [try on Beta](https://www.google.com/intl/it/chrome/beta/), will be out first days of December 2019)\r\n- Reproducible Code Snippet or URL:\r\n\r\nJust open an aframe application with Chrome 79 beta.\r\nOtherwise, look here:\r\n\r\n* open this link, it's an app using latest aframe : https://nicolo-carpignoli.herokuapp.com/examples/places-name/\r\n\r\n* open console\r\n\r\n* you can see the error. it's from device.js file, error is in accessing `navigator.xr.requestDevice` that is not present. APIs are changed lately. Code needs to be changed simply with a sanity check.\r\n\r\nThis potentially breaks *every* aframe app. \r\n\r\nThanks for the attention\r\n"},
#    'comment': {'url': 'https://api.github.com/repos/aframevr/aframe/issues/comments/567275236',
#     'html_url': 'https://github.com/aframevr/aframe/issues/4317#issuecomment-567275236',
#     'issue_url': 'https://api.github.com/repos/aframevr/aframe/issues/4317',
#     'id': 567275236,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU2NzI3NTIzNg==',
#     'user': {'login': 'felipenmoura',
#      'id': 347387,
#      'node_id': 'MDQ6VXNlcjM0NzM4Nw==',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/347387?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/felipenmoura',
#      'html_url': 'https://github.com/felipenmoura',
#      'followers_url': 'https://api.github.com/users/felipenmoura/followers',
#      'following_url': 'https://api.github.com/users/felipenmoura/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/felipenmoura/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/felipenmoura/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/felipenmoura/subscriptions',
#      'organizations_url': 'https://api.github.com/users/felipenmoura/orgs',
#      'repos_url': 'https://api.github.com/users/felipenmoura/repos',
#      'events_url': 'https://api.github.com/users/felipenmoura/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/felipenmoura/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-12-19T00:34:01Z',
#     'updated_at': '2019-12-19T00:34:01Z',
#     'author_association': 'NONE',
#     'body': 'Hi @klausw \r\nI left a better description (and code) about it here:\r\nhttps://github.com/aframevr/aframe/issues/4354#issuecomment-566792431\r\n\r\nThen, I posted a "quick fix" for it here:\r\nhttps://github.com/aframevr/aframe/issues/4354#issuecomment-567052948\r\n\r\nBut that fix is an ugly workaround and I ended up not being able to use the 1.0.0 version of a-frame!'}},
#   'public': True,
#   'created_at': '2019-12-19T00:34:01Z',
#   'org': {'id': 16024092,
#    'login': 'aframevr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/aframevr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16024092?'}},
#  {'id': '11121573959',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 46622658,
#    'name': 'Lombiq/Orchard-JavaScript.Net',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard-JavaScript.Net'},
#   'payload': {'push_id': 4414641414,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/orchard-upgrade-1.9.3',
#    'head': 'b98d1d2a0a83de51260dc90993206de09490252e',
#    'before': 'b98d1d2a0a83de51260dc90993206de09490252e',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-12-19T00:34:01Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '11121573956',
#   'type': 'CreateEvent',
#   'actor': {'id': 53956182,
#    'login': 'chuhaovince',
#    'display_login': 'chuhaovince',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chuhaovince',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53956182?'},
#   'repo': {'id': 228944070,
#    'name': 'chuhaovince/DataBootCamp_ETL_Project',
#    'url': 'https://api.github.com/repos/chuhaovince/DataBootCamp_ETL_Project'},
#   'payload': {'ref': 'Release',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-19T00:34:01Z'},
#  {'id': '11121573946',
#   'type': 'PushEvent',
#   'actor': {'id': 16469357,
#    'login': 'theejdavidson',
#    'display_login': 'theejdavidson',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/theejdavidson',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16469357?'},
#   'repo': {'id': 228261448,
#    'name': 'theejdavidson/VisExp',
#    'url': 'https://api.github.com/repos/theejdavidson/VisExp'},
#   'payload': {'push_id': 4414641407,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1d10276513b2f4538600f7a520a693cf4dee0cbc',
#    'before': '4a5726aff709ca9773c6a6b4485b983c0f92059e',
#    'commits': [{'sha': '1d10276513b2f4538600f7a520a693cf4dee0cbc',
#      'author': {'email': 'theejdavidson@gmail.com', 'name': 'Ethan'},
#      'message': 'it is always darkest before the dawn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/theejdavidson/VisExp/commits/1d10276513b2f4538600f7a520a693cf4dee0cbc'}]},
#   'public': True,
#   'created_at': '2019-12-19T00:34:01Z'},
#  {'id': '11121573944',
#   'type': 'PushEvent',
#   'actor': {'id': 13488485,
#    'login': 'LuckyCyborg',
#    'display_login': 'LuckyCyborg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LuckyCyborg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13488485?'},
#   'repo': {'id': 160575122,
#    'name': 'nova-framework/mini',
#    'url': 'https://api.github.com/repos/nova-framework/mini'},
#   'payload': {'push_id': 4414641405,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ce1a540343a4a52ed0fadb014d4049e8dbb65f4d',
#    'before': '8488305fc52a3d3850bd324a2b80e02580c183b1',
#    'commits': [{'sha': 'ce1a540343a4a52ed0fadb014d4049e8dbb65f4d',
#      'author': {'email': 'darkstarlinux@gmail.com',
#       'name': 'Virgil-Adrian Teaca'},
#      'message': 'Improve the Routing',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nova-framework/mini/commits/ce1a540343a4a52ed0fadb014d4049e8dbb65f4d'}]},
#   'public': True,
#   'created_at': '2019-12-19T00:34:01Z',
#   'org': {'id': 7198958,
#    'login': 'nova-framework',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/nova-framework',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7198958?'}},
#  {'id': '11121573930',
#   'type': 'PushEvent',
#   'actor': {'id': 19782419,
#    'login': 'butanido',
#    'display_login': 'butanido',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/butanido',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19782419?'},
#   'repo': {'id': 202637881,
#    'name': 'Mageco/virtualpet',
#    'url': 'https://api.github.com/repos/Mageco/virtualpet'},
#   'payload': {'push_id': 4414641397,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '846742dcbc1372e9baf7351d20ab28086d22dd7e',
#    'before': '30ea778b0b4120331a3c54252601b090b331ce59',
#    'commits': [{'sha': '846742dcbc1372e9baf7351d20ab28086d22dd7e',
#      'author': {'email': 'butanido@gmail.com', 'name': 'Bui Tuan Nghia'},
#      'message': 'Update Mage Engine',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Mageco/virtualpet/commits/846742dcbc1372e9baf7351d20ab28086d22dd7e'}]},
#   'public': True,
#   'created_at': '2019-12-19T00:34:00Z'},
#  {'id': '11121573938',
#   'type': 'CreateEvent',
#   'actor': {'id': 59036038,
#    'login': 'Youngkillabean',
#    'display_login': 'Youngkillabean',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Youngkillabean',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59036038?'},
#   'repo': {'id': 228944712,
#    'name': 'Youngkillabean/bruh-momento',
#    'url': 'https://api.github.com/repos/Youngkillabean/bruh-momento'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-19T00:34:01Z'},
#  {'id': '11121573928',
#   'type': 'IssuesEvent',
#   'actor': {'id': 51377557,
#    'login': 'iamhopaul123',
#    'display_login': 'iamhopaul123',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/iamhopaul123',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51377557?'},
#   'repo': {'id': 202018792,
#    'name': 'aws/amazon-ecs-cli-v2',
#    'url': 'https://api.github.com/repos/aws/amazon-ecs-cli-v2'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/aws/amazon-ecs-cli-v2/issues/515',
#     'repository_url': 'https://api.github.com/repos/aws/amazon-ecs-cli-v2',
#     'labels_url': 'https://api.github.com/repos/aws/amazon-ecs-cli-v2/issues/515/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/aws/amazon-ecs-cli-v2/issues/515/comments',
#     'events_url': 'https://api.github.com/repos/aws/amazon-ecs-cli-v2/issues/515/events',
#     'html_url': 'https://github.com/aws/amazon-ecs-cli-v2/issues/515',
#     'id': 533057352,
#     'node_id': 'MDU6SXNzdWU1MzMwNTczNTI=',
#     'number': 515,
#     'title': 'Pipeline init does not have validation for flags',
#     'user': {'login': 'iamhopaul123',
#      'id': 51377557,
#      'node_id': 'MDQ6VXNlcjUxMzc3NTU3',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/51377557?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/iamhopaul123',
#      'html_url': 'https://github.com/iamhopaul123',
#      'followers_url': 'https://api.github.com/users/iamhopaul123/followers',
#      'following_url': 'https://api.github.com/users/iamhopaul123/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/iamhopaul123/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/iamhopaul123/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/iamhopaul123/subscriptions',
#      'organizations_url': 'https://api.github.com/users/iamhopaul123/orgs',
#      'repos_url': 'https://api.github.com/users/iamhopaul123/repos',
#      'events_url': 'https://api.github.com/users/iamhopaul123/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/iamhopaul123/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1623131212,
#       'node_id': 'MDU6TGFiZWwxNjIzMTMxMjEy',
#       'url': 'https://api.github.com/repos/aws/amazon-ecs-cli-v2/labels/pipeline',
#       'name': 'pipeline',
#       'color': '60f760',
#       'default': False,
#       'description': 'Issues related to the archer pipeline command'}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': {'login': 'iamhopaul123',
#      'id': 51377557,
#      'node_id': 'MDQ6VXNlcjUxMzc3NTU3',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/51377557?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/iamhopaul123',
#      'html_url': 'https://github.com/iamhopaul123',
#      'followers_url': 'https://api.github.com/users/iamhopaul123/followers',
#      'following_url': 'https://api.github.com/users/iamhopaul123/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/iamhopaul123/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/iamhopaul123/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/iamhopaul123/subscriptions',
#      'organizations_url': 'https://api.github.com/users/iamhopaul123/orgs',
#      'repos_url': 'https://api.github.com/users/iamhopaul123/repos',
#      'events_url': 'https://api.github.com/users/iamhopaul123/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/iamhopaul123/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'iamhopaul123',
#       'id': 51377557,
#       'node_id': 'MDQ6VXNlcjUxMzc3NTU3',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/51377557?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/iamhopaul123',
#       'html_url': 'https://github.com/iamhopaul123',
#       'followers_url': 'https://api.github.com/users/iamhopaul123/followers',
#       'following_url': 'https://api.github.com/users/iamhopaul123/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/iamhopaul123/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/iamhopaul123/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/iamhopaul123/subscriptions',
#       'organizations_url': 'https://api.github.com/users/iamhopaul123/orgs',
#       'repos_url': 'https://api.github.com/users/iamhopaul123/repos',
#       'events_url': 'https://api.github.com/users/iamhopaul123/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/iamhopaul123/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-12-05T01:01:26Z',
#     'updated_at': '2019-12-19T00:34:00Z',
#     'closed_at': '2019-12-19T00:34:00Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': '`pipeline init` has following flags and some of them needs validation.\r\n\r\n- --environments (need validation for env existence)\r\n\r\n- --github-access-token\r\n\r\n- --github-branch (need validation related #509)\r\n\r\n- --github-url (need validation for string matching)'}},
#   'public': True,
#   'created_at': '2019-12-19T00:34:00Z',
#   'org': {'id': 2232217,
#    'login': 'aws',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/aws',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2232217?'}},
#  {'id': '11121573920',
#   'type': 'PushEvent',
#   'actor': {'id': 2544838,
#    'login': 'snoopycrimecop',
#    'display_login': 'snoopycrimecop',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/snoopycrimecop',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2544838?'},
#   'repo': {'id': 200829457,
#    'name': 'snoopycrimecop/omero-python-superbuild',
#    'url': 'https://api.github.com/repos/snoopycrimecop/omero-python-superbuild'},
#   'payload': {'push_id': 4414641388,
#    'size': 4,
#    'distinct_size': 3,
#    'ref': 'refs/heads/py3_ci',
#    'head': 'a9d758f890b85c76009ef02d8aa351beac179e7b',
#    'before': '67643749cf9735b4dce5897c643b74d7afc12665',
#    'commits': [{'sha': 'e5d57164bbaf7caee52c4da2f9089a66fc43d881',
#      'author': {'email': 'snoopycrimecop@gmail.com',
#       'name': 'Snoopy Crime Cop'},
#      'message': "Update master submodules\n\nRepository: ome/omero-python-superbuild\nAlready up-to-date.\n\nRepository: ome/omero-dropbox\nAlready up-to-date.\n\nRepository: ome/omero-marshal\nAlready up-to-date.\n\nRepository: ome/omero-py\nUpdating 9ae8bcf..12361a8\nPreviously merged:\n  - PR 148 will-moore 'Ignore OMERO_HOME in bin/omero with warning'\n  - PR 150 joshmoore 'processor: pass locale to subprocesses'\n  - PR 149 manics 'omero.client ensure args is not None'\n\nRepository: ome/omero-scripts\nAlready up-to-date.\n\nRepository: ome/omero-web\nUpdating 95f5bc3..1cc447a\nPreviously merged:\n  - PR 98 will-moore 'Ignore OMERO_HOME in omeroweb/settings.py'\n  - PR 22 will-moore 'Filter by map anns webclient'\n  - PR 24 will-moore 'Handle lookupLdapAuthExperimenter exception'\n\nGenerated by OMERO-PYTHON-SUPERBUILD-submodules#24 (https://ci.openmicroscopy.org/job/OMERO-PYTHON-SUPERBUILD-submodules/24/)",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/snoopycrimecop/omero-python-superbuild/commits/e5d57164bbaf7caee52c4da2f9089a66fc43d881'},
#     {'sha': 'd88d8eec68ebf08916d5bda0ff95bfff29c10558',
#      'author': {'email': 'snoopycrimecop@gmail.com',
#       'name': 'Snoopy Crime Cop'},
#      'message': 'merge master -Dorg -Snone: PR 9 (Update master submodules)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/snoopycrimecop/omero-python-superbuild/commits/d88d8eec68ebf08916d5bda0ff95bfff29c10558'},
#     {'sha': '8d5bd03ba8860cf45f8cae279c465dc46e90297a',
#      'author': {'email': 'snoopycrimecop@gmail.com',
#       'name': 'Snoopy Crime Cop'},
#      'message': "merge master -Dorg -Snone\n\nRepository: ome/omero-python-superbuild\nAlready up-to-date.\n\nMerged PRs:\n  - PR 9 snoopycrimecop 'Update master submodules'\n\nGenerated by OMERO-python-superbuild-push#197 (https://py3-ci.openmicroscopy.org/jenkins/job/OMERO-python-superbuild-push/197/)",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/snoopycrimecop/omero-python-superbuild/commits/8d5bd03ba8860cf45f8cae279c465dc46e90297a'},
#     {'sha': 'a9d758f890b85c76009ef02d8aa351beac179e7b',
#      'author': {'email': 'snoopycrimecop@gmail.com',
#       'name': 'Snoopy Crime Cop'},
#      'message': "merge master -Dorg -Ssuccess-only\n\nRepository: ome/omero-python-superbuild\nAlready up-to-date.\n\nMerged PRs:\n  - PR 9 snoopycrimecop 'Update master submodules'\n\nRepository: ome/omero-dropbox\nAlready up-to-date.\n\nRepository: ome/omero-marshal\nExcluded PRs:\n  - PR 33 chris-allan 'Encode/Decode Experimenters with ExperimenterGroup' (exclude comment)\nAlready up-to-date.\n\nMerged PRs:\n  - PR 29 chris-allan 'Initial support for FileAnnotation and OriginalFile'\n  - PR 64 manics 'import omero.all to avoid ordering errors'\n\nConflicting PRs (not included):\n  - PR 34 chris-allan 'Initial support for Event'\n\nRepository: ome/omero-py\nExcluded PRs:\n  - PR 134 joshmoore 'travis jobs: enable Windows' (status: failure)\n  - PR 115 manics 'Remove omero_ext.argparse' (exclude comment)\nAlready up-to-date.\n\nMerged PRs:\n  - PR 114 manics 'First attempt at adding optional packages'\n  - PR 129 dominikl 'Add option to create new ThumbnailStore connection'\n  - PR 141 manics 'Reenable testLoadGlob'\n  - PR 145 manics 'StringColumn: Handle all encoding inside class'\n  - PR 151 joshmoore 'CmdError: implement __str__'\n  - PR 152 joshmoore 'tables: call delete callback'\n\nRepository: ome/omero-scripts\nAlready up-to-date.\n\nMerged PRs:\n  - PR 103 joshmoore 'Script for calculating min/max'\n  - PR 152 will-moore 'populate metadata links file ann'\n  - PR 156 will-moore 'Batch_ROI_Export.py supports Screen, Plate, Project'\n  - PR 165 will-moore 'batch ROI export CSV unicode'\n\nRepository: ome/omero-web\nExcluded PRs:\n  - PR 64 manics 'Remove omero_ext.argparse' (exclude comment)\n  - PR 63 manics 'Web templating with Jinja 2' (status: failure)\nAlready up-to-date.\n\nMerged PRs:\n  - PR 3 will-moore 'table download'\n  - PR 4 manics 'OMERO.web use client (browser) timezone'\n  - PR 100 manics 'web requires OMERODIR'\n\nConflicting PRs (not included):\n  - PR 17 will-moore 'Right panel performance fixes'\n\nGenerated by OMERO-python-superbuild-push#197 (https://py3-ci.openmicroscopy.org/jenkins/job/OMERO-python-superbuild-push/197/)",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/snoopycrimecop/omero-python-superbuild/commits/a9d758f890b85c76009ef02d8aa351beac179e7b'}]},
#   'public': True,
#   'created_at': '2019-12-19T00:34:00Z'},
#  {'id': '11121573925',
#   'type': 'PushEvent',
#   'actor': {'id': 3596885,
#    'login': 'thomasNDS',
#    'display_login': 'thomasNDS',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/thomasNDS',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3596885?'},
#   'repo': {'id': 102862767,
#    'name': 'thomasNDS/lbl',
#    'url': 'https://api.github.com/repos/thomasNDS/lbl'},
#   'payload': {'push_id': 4414641392,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8f5b2982daaeb7ca7d8784c4004009d5e5a43e38',
#    'before': 'af38ab55176930c36e29298236d41dde63ebd958',
#    'commits': [{'sha': '8f5b2982daaeb7ca7d8784c4004009d5e5a43e38',
#      'author': {'email': 'nds.thomas@gmail.com', 'name': 'Thomas Nunes'},
#      'message': 'update state',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/thomasNDS/lbl/commits/8f5b2982daaeb7ca7d8784c4004009d5e5a43e38'}]},
#   'public': True,
#   'created_at': '2019-12-19T00:34:00Z'},
#  {'id': '11121573919',
#   'type': 'PushEvent',
#   'actor': {'id': 46336983,
#    'login': 'LuShan123888',
#    'display_login': 'LuShan123888',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LuShan123888',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46336983?'},
#   'repo': {'id': 216305317,
#    'name': 'LuShan123888/lushan123888.github.io',
#    'url': 'https://api.github.com/repos/LuShan123888/lushan123888.github.io'},
#   'payload': {'push_id': 4414641394,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2a25a2185e4213cdfd1ddf0b0423d1a4a3bf8e2a',
#    'before': '518fd7694bdc7da295ea2b7171bfe02c10d2cfa8',
#    'commits': [{'sha': '2a25a2185e4213cdfd1ddf0b0423d1a4a3bf8e2a',
#      'author': {'email': 'lushan123888@gmail.com', 'name': 'lushan123888'},
#      'message': 'edit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/LuShan123888/lushan123888.github.io/commits/2a25a2185e4213cdfd1ddf0b0423d1a4a3bf8e2a'}]},
#   'public': True,
#   'created_at': '2019-12-19T00:34:00Z'},
#  {'id': '11121573914',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 16144326,
#    'login': 'NathanielBlairStahn',
#    'display_login': 'NathanielBlairStahn',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NathanielBlairStahn',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16144326?'},
#   'repo': {'id': 195448838,
#    'name': 'ihmeuw/vivarium_research',
#    'url': 'https://api.github.com/repos/ihmeuw/vivarium_research'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/ihmeuw/vivarium_research/pulls/comments/359637243',
#     'pull_request_review_id': 334348619,
#     'id': 359637243,
#     'node_id': 'MDI0OlB1bGxSZXF1ZXN0UmV2aWV3Q29tbWVudDM1OTYzNzI0Mw==',
#     'diff_hunk': "@@ -558,6 +558,53 @@ below.\n Remission Rates\n ^^^^^^^^^^^^^^^\n \n+**Definition**\n+\n+Remission is a measure of cases that recover from a with-condition state, given \n+a specified population and time period. Just as with incidence, the numerator is \n+given by the count of recovered (or *remitted*) cases, and the denominator is \n+the cumulative person-time [link to person-time definition in incidence \n+section] during which cases are able to go into remission.\n+\n+  For example, consider diarrhea cases in the Philippines in 2017. Say there\n+  were 1 million prevalent cases of diarrhea over the course of 2017, and each\n+  case remitted after an average of 5 days. The way we define this remission\n+  rate depends on the denominator we choose; some examples include:\n+\n+.. math::\n+\t\n+\t\\frac{\\text{1/5 case}}{\\text{1 person-days}}=\\frac{365/5\\text{ cases}}{\\text{1\n+   person-year}}=73\\text{ cases/person-year}\n+ \n+Note that, unlike incidence, there is not a strong precedent for referring to \n+remission rates within the entire population; rather, remission rates typically \n+refer to rates within an infected, or with-condition population. {Is this true? \n+This is based on limited google searching!}\n+\n+**Remission within GBD**\n+\n+Most nonfatal models in GBD are run using DisMod [link to DisMod page]. DisMod \n+estimates compartmental models of disease, which includes an estimate of \n+remission in terms of **{remitted cases in the with-condition population} per \n+{person-year}**. Thus DisMod's estimates of various measures (prevalence, \n+incidence, remission, excess mortality rate, etc.) are internally consistent for ",
#     'path': 'docs/source/models/cause.rst',
#     'position': 33,
#     'original_position': 33,
#     'commit_id': 'e63c5d566ecbe607ece28ac408e8f6e514307a14',
#     'original_commit_id': 'e63c5d566ecbe607ece28ac408e8f6e514307a14',
#     'user': {'login': 'NathanielBlairStahn',
#      'id': 16144326,
#      'node_id': 'MDQ6VXNlcjE2MTQ0MzI2',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/16144326?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/NathanielBlairStahn',
#      'html_url': 'https://github.com/NathanielBlairStahn',
#      'followers_url': 'https://api.github.com/users/NathanielBlairStahn/followers',
#      'following_url': 'https://api.github.com/users/NathanielBlairStahn/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/NathanielBlairStahn/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/NathanielBlairStahn/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/NathanielBlairStahn/subscriptions',
#      'organizations_url': 'https://api.github.com/users/NathanielBlairStahn/orgs',
#      'repos_url': 'https://api.github.com/users/NathanielBlairStahn/repos',
#      'events_url': 'https://api.github.com/users/NathanielBlairStahn/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/NathanielBlairStahn/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Are there more measures DisMod estimates that go into the "etc.", or are these the only four measures?',
#     'created_at': '2019-12-19T00:33:59Z',
#     'updated_at': '2019-12-19T00:34:00Z',
#     'html_url': 'https://github.com/ihmeuw/vivarium_research/pull/70#discussion_r359637243',
#     'pull_request_url': 'https://api.github.com/repos/ihmeuw/vivarium_research/pulls/70',
#     'author_association': 'CONTRIBUTOR',
#     '_links': {'self': {'href': 'https://api.github.com/repos/ihmeuw/vivarium_research/pulls/comments/359637243'},
#      'html': {'href': 'https://github.com/ihmeuw/vivarium_research/pull/70#discussion_r359637243'},
#      'pull_request': {'href': 'https://api.github.com/repos/ihmeuw/vivarium_research/pulls/70'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/ihmeuw/vivarium_research/pulls/70',
#     'id': 354796042,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzU0Nzk2MDQy',
#     'html_url': 'https://github.com/ihmeuw/vivarium_research/pull/70',
#     'diff_url': 'https://github.com/ihmeuw/vivarium_research/pull/70.diff',
#     'patch_url': 'https://github.com/ihmeuw/vivarium_research/pull/70.patch',
#     'issue_url': 'https://api.github.com/repos/ihmeuw/vivarium_research/issues/70',
#     'number': 70,
#     'state': 'open',
#     'locked': False,
#     'title': 'Added remission section to cause page',
#     'user': {'login': 'beatrixkh',
#      'id': 57412727,
#      'node_id': 'MDQ6VXNlcjU3NDEyNzI3',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/57412727?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/beatrixkh',
#      'html_url': 'https://github.com/beatrixkh',
#      'followers_url': 'https://api.github.com/users/beatrixkh/followers',
#      'following_url': 'https://api.github.com/users/beatrixkh/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/beatrixkh/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/beatrixkh/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/beatrixkh/subscriptions',
#      'organizations_url': 'https://api.github.com/users/beatrixkh/orgs',
#      'repos_url': 'https://api.github.com/users/beatrixkh/repos',
#      'events_url': 'https://api.github.com/users/beatrixkh/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/beatrixkh/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "In addition to flagging errors/suggestions re:the content already here, I have two types of questions:\r\n\r\n1. To what degree should this (or any given section on this page) be able to stand alone?\r\n- Some of what I've written is redundant with the DisMod description--do we want to keep it in?\r\n- I left out some definitions (such as person-time) that are defined directly above, in the incidence section. \r\n2. Are there sections to add?\r\n- I went into much less detail than Ali's incidence section, because these are so similar. However, I can add further examples and considerations analogous to her section.",
#     'created_at': '2019-12-18T20:10:25Z',
#     'updated_at': '2019-12-19T00:34:00Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'f787f0454b194dbcf9df9afdd393e94b6c72a7a7',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [{'login': 'collijk',
#       'id': 6313865,
#       'node_id': 'MDQ6VXNlcjYzMTM4NjU=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/6313865?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/collijk',
#       'html_url': 'https://github.com/collijk',
#       'followers_url': 'https://api.github.com/users/collijk/followers',
#       'following_url': 'https://api.github.com/users/collijk/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/collijk/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/collijk/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/collijk/subscriptions',
#       'organizations_url': 'https://api.github.com/users/collijk/orgs',
#       'repos_url': 'https://api.github.com/users/collijk/repos',
#       'events_url': 'https://api.github.com/users/collijk/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/collijk/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'SantoniS',
#       'id': 14587197,
#       'node_id': 'MDQ6VXNlcjE0NTg3MTk3',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/14587197?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/SantoniS',
#       'html_url': 'https://github.com/SantoniS',
#       'followers_url': 'https://api.github.com/users/SantoniS/followers',
#       'following_url': 'https://api.github.com/users/SantoniS/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/SantoniS/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/SantoniS/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/SantoniS/subscriptions',
#       'organizations_url': 'https://api.github.com/users/SantoniS/orgs',
#       'repos_url': 'https://api.github.com/users/SantoniS/repos',
#       'events_url': 'https://api.github.com/users/SantoniS/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/SantoniS/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'yongqx',
#       'id': 24902895,
#       'node_id': 'MDQ6VXNlcjI0OTAyODk1',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/24902895?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/yongqx',
#       'html_url': 'https://github.com/yongqx',
#       'followers_url': 'https://api.github.com/users/yongqx/followers',
#       'following_url': 'https://api.github.com/users/yongqx/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/yongqx/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/yongqx/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/yongqx/subscriptions',
#       'organizations_url': 'https://api.github.com/users/yongqx/orgs',
#       'repos_url': 'https://api.github.com/users/yongqx/repos',
#       'events_url': 'https://api.github.com/users/yongqx/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/yongqx/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'ctroeger',
#       'id': 29927666,
#       'node_id': 'MDQ6VXNlcjI5OTI3NjY2',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/29927666?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ctroeger',
#       'html_url': 'https://github.com/ctroeger',
#       'followers_url': 'https://api.github.com/users/ctroeger/followers',
#       'following_url': 'https://api.github.com/users/ctroeger/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ctroeger/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ctroeger/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ctroeger/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ctroeger/orgs',
#       'repos_url': 'https://api.github.com/users/ctroeger/repos',
#       'events_url': 'https://api.github.com/users/ctroeger/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ctroeger/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'kiranklc',
#       'id': 46701264,
#       'node_id': 'MDQ6VXNlcjQ2NzAxMjY0',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/46701264?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/kiranklc',
#       'html_url': 'https://github.com/kiranklc',
#       'followers_url': 'https://api.github.com/users/kiranklc/followers',
#       'following_url': 'https://api.github.com/users/kiranklc/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/kiranklc/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/kiranklc/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/kiranklc/subscriptions',
#       'organizations_url': 'https://api.github.com/users/kiranklc/orgs',
#       'repos_url': 'https://api.github.com/users/kiranklc/repos',
#       'events_url': 'https://api.github.com/users/kiranklc/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/kiranklc/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'alibow',
#       'id': 54918472,
#       'node_id': 'MDQ6VXNlcjU0OTE4NDcy',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/54918472?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/alibow',
#       'html_url': 'https://github.com/alibow',
#       'followers_url': 'https://api.github.com/users/alibow/followers',
#       'following_url': 'https://api.github.com/users/alibow/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/alibow/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/alibow/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/alibow/subscriptions',
#       'organizations_url': 'https://api.github.com/users/alibow/orgs',
#       'repos_url': 'https://api.github.com/users/alibow/repos',
#       'events_url': 'https://api.github.com/users/alibow/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/alibow/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'XiaoluQianUW',
#       'id': 56012906,
#       'node_id': 'MDQ6VXNlcjU2MDEyOTA2',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/56012906?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/XiaoluQianUW',
#       'html_url': 'https://github.com/XiaoluQianUW',
#       'followers_url': 'https://api.github.com/users/XiaoluQianUW/followers',
#       'following_url': 'https://api.github.com/users/XiaoluQianUW/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/XiaoluQianUW/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/XiaoluQianUW/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/XiaoluQianUW/subscriptions',
#       'organizations_url': 'https://api.github.com/users/XiaoluQianUW/orgs',
#       'repos_url': 'https://api.github.com/users/XiaoluQianUW/repos',
#       'events_url': 'https://api.github.com/users/XiaoluQianUW/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/XiaoluQianUW/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'yaqi7',
#       'id': 56321099,
#       'node_id': 'MDQ6VXNlcjU2MzIxMDk5',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/56321099?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/yaqi7',
#       'html_url': 'https://github.com/yaqi7',
#       'followers_url': 'https://api.github.com/users/yaqi7/followers',
#       'following_url': 'https://api.github.com/users/yaqi7/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/yaqi7/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/yaqi7/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/yaqi7/subscriptions',
#       'organizations_url': 'https://api.github.com/users/yaqi7/orgs',
#       'repos_url': 'https://api.github.com/users/yaqi7/repos',
#       'events_url': 'https://api.github.com/users/yaqi7/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/yaqi7/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'Ninicorn',
#       'id': 57811075,
#       'node_id': 'MDQ6VXNlcjU3ODExMDc1',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/57811075?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Ninicorn',
#       'html_url': 'https://github.com/Ninicorn',
#       'followers_url': 'https://api.github.com/users/Ninicorn/followers',
#       'following_url': 'https://api.github.com/users/Ninicorn/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Ninicorn/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Ninicorn/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Ninicorn/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Ninicorn/orgs',
#       'repos_url': 'https://api.github.com/users/Ninicorn/repos',
#       'events_url': 'https://api.github.com/users/Ninicorn/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Ninicorn/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/ihmeuw/vivarium_research/pulls/70/commits',
#     'review_comments_url': 'https://api.github.com/repos/ihmeuw/vivarium_research/pulls/70/comments',
#     'review_comment_url': 'https://api.github.com/repos/ihmeuw/vivarium_research/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/ihmeuw/vivarium_research/issues/70/comments',
#     'statuses_url': 'https://api.github.com/repos/ihmeuw/vivarium_research/statuses/e63c5d566ecbe607ece28ac408e8f6e514307a14',
#     'head': {'label': 'ihmeuw:feature/cause_remission',
#      'ref': 'feature/cause_remission',
#      'sha': 'e63c5d566ecbe607ece28ac408e8f6e514307a14',
#      'user': {'login': 'ihmeuw',
#       'id': 4683173,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ2ODMxNzM=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/4683173?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ihmeuw',
#       'html_url': 'https://github.com/ihmeuw',
#       'followers_url': 'https://api.github.com/users/ihmeuw/followers',
#       'following_url': 'https://api.github.com/users/ihmeuw/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ihmeuw/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ihmeuw/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ihmeuw/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ihmeuw/orgs',
#       'repos_url': 'https://api.github.com/users/ihmeuw/repos',
#       'events_url': 'https://api.github.com/users/ihmeuw/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ihmeuw/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 195448838,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTU0NDg4Mzg=',
#       'name': 'vivarium_research',
#       'full_name': 'ihmeuw/vivarium_research',
#       'private': False,
#       'owner': {'login': 'ihmeuw',
#        'id': 4683173,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ2ODMxNzM=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/4683173?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ihmeuw',
#        'html_url': 'https://github.com/ihmeuw',
#        'followers_url': 'https://api.github.com/users/ihmeuw/followers',
#        'following_url': 'https://api.github.com/users/ihmeuw/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ihmeuw/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ihmeuw/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ihmeuw/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ihmeuw/orgs',
#        'repos_url': 'https://api.github.com/users/ihmeuw/repos',
#        'events_url': 'https://api.github.com/users/ihmeuw/events{/privacy}',
# ...
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CircleJanewayTest',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42873674?'},
#   'repo': {'id': 164702370,
#    'name': 'CircleCITestOrg/smoke-test-test-repo',
#    'url': 'https://api.github.com/repos/CircleCITestOrg/smoke-test-test-repo'},
#   'payload': {'ref': 'build-macos-2019-12-19T00-33-47',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-19T00:34:00Z',
#   'org': {'id': 32499712,
#    'login': 'CircleCITestOrg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/CircleCITestOrg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32499712?'}},
#  {'id': '11121573905',
#   'type': 'PushEvent',
#   'actor': {'id': 50577526,
#    'login': 'EnzoChou',
#    'display_login': 'EnzoChou',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/EnzoChou',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50577526?'},
#   'repo': {'id': 216207726,
#    'name': 'EnzoChou/FreakCircus',
#    'url': 'https://api.github.com/repos/EnzoChou/FreakCircus'},
#   'payload': {'push_id': 4414641382,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '38defe7472556acaec8fc50a6ba46ae0c483dac4',
#    'before': '4d38026db456f11f763e3d10f28a7fe77721c36a',
#    'commits': [{'sha': '38defe7472556acaec8fc50a6ba46ae0c483dac4',
#      'author': {'email': 'Christ8818@hotmail.it', 'name': 'Christ8818'},
#      'message': "audio bottoni menu\n\naggiunto l'audio anche per i bottoni del menu",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/EnzoChou/FreakCircus/commits/38defe7472556acaec8fc50a6ba46ae0c483dac4'}]},
#   'public': True,
#   'created_at': '2019-12-19T00:34:00Z'},
#  {'id': '11121573900',
#   'type': 'PushEvent',
#   'actor': {'id': 42790816,
#    'login': 'hermantw',
#    'display_login': 'hermantw',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hermantw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42790816?'},
#   'repo': {'id': 206894113,
#    'name': 'hermantw/HermanTW.github.io',
#    'url': 'https://api.github.com/repos/hermantw/HermanTW.github.io'},
#   'payload': {'push_id': 4414641384,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e9b2ac9e4fddecbcc54ef10d941903b626703aa6',
#    'before': 'ebad969fe59f1e3ee7695bff4356265a62088357',
#    'commits': [{'sha': 'e9b2ac9e4fddecbcc54ef10d941903b626703aa6',
#      'author': {'email': '42790816+hermantw@users.noreply.github.com',
#       'name': 'hermantw'},
#      'message': 'Update (Frame)Work-Hard-Play-Hard.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hermantw/HermanTW.github.io/commits/e9b2ac9e4fddecbcc54ef10d941903b626703aa6'}]},
#   'public': True,
#   'created_at': '2019-12-19T00:34:00Z'},
#  {'id': '11121573884',
#   'type': 'PushEvent',
#   'actor': {'id': 24241698,
#    'login': 'smoothlearning',
#    'display_login': 'smoothlearning',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/smoothlearning',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24241698?'},
#   'repo': {'id': 226489173,
#    'name': 'swflab/Patterns',
#    'url': 'https://api.github.com/repos/swflab/Patterns'},
#   'payload': {'push_id': 4414641374,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/master',
#    'head': '3b1b80337f8df547cad1ee88e3781d89c49774be',
#    'before': 'fb0d892c2ab2059d16a9f9ba7fd23feff800691b',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-12-19T00:34:00Z',
#   'org': {'id': 58586531,
#    'login': 'swflab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/swflab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58586531?'}},
#  {'id': '11121573896',
#   'type': 'PushEvent',
#   'actor': {'id': 44930447,
#    'login': 'graydon127',
#    'display_login': 'graydon127',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/graydon127',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44930447?'},
#   'repo': {'id': 228942007,
#    'name': 'graydon127/Jungle-Raid',
#    'url': 'https://api.github.com/repos/graydon127/Jungle-Raid'},
#   'payload': {'push_id': 4414641380,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '428a104dbff72d9d70dc5e382ac5233c5fc2cdcb',
#    'before': 'ed76f4ea62f4b96009b71c553206856f508b4d4e',
#    'commits': [{'sha': '428a104dbff72d9d70dc5e382ac5233c5fc2cdcb',
#      'author': {'email': '44930447+graydon127@users.noreply.github.com',
#       'name': 'graydon127'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/graydon127/Jungle-Raid/commits/428a104dbff72d9d70dc5e382ac5233c5fc2cdcb'}]},
#   'public': True,
#   'created_at': '2019-12-19T00:34:00Z'},
#  {'id': '11121573886',
#   'type': 'PushEvent',
#   'actor': {'id': 311108,
#    'login': 'jonkensta',
#    'display_login': 'jonkensta',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jonkensta',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/311108?'},
#   'repo': {'id': 91115114,
#    'name': 'jonkensta/ibp',
#    'url': 'https://api.github.com/repos/jonkensta/ibp'},
#   'payload': {'push_id': 4414641379,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/python2to3',
#    'head': 'ba25af2c41406ec5d6bc6d319e925fcf925a8e07',
#    'before': '09330dec3c7e8ef63794522163465bdf48dca386',
#    'commits': [{'sha': 'ba25af2c41406ec5d6bc6d319e925fcf925a8e07',
#      'author': {'email': 'jstarr@carnegietechnologies.com',
#       'name': 'Jonathan Starr'},
#      'message': 'Add API endpoints for comments and requests',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jonkensta/ibp/commits/ba25af2c41406ec5d6bc6d319e925fcf925a8e07'}]},
#   'public': True,
#   'created_at': '2019-12-19T00:34:00Z'},
#  {'id': '11121573893',
#   'type': 'PushEvent',
#   'actor': {'id': 35667247,
#    'login': 'm-uszynski',
#    'display_login': 'm-uszynski',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/m-uszynski',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35667247?'},
#   'repo': {'id': 228684186,
#    'name': 'm-uszynski/mySong',
#    'url': 'https://api.github.com/repos/m-uszynski/mySong'},
#   'payload': {'push_id': 4414641378,
#    'size': 19,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a4fdb363962174a2ee9d49623f611c1719c75e9f',
#    'before': 'c0bdb6a1fb5c15362d1b07ac19b8d4e1249b340e',
#    'commits': [{'sha': '6e697a2e11bdbce7b1976eaeb7a68ca882b5e970',
#      'author': {'email': 'rtck@o2.pl', 'name': 'Mateusz Uszyński'},
#      'message': 'Init Android App',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/m-uszynski/mySong/commits/6e697a2e11bdbce7b1976eaeb7a68ca882b5e970'},
#     {'sha': '3300dd8918fa54202768018a012cf5f831fed517',
#      'author': {'email': 'rtck@o2.pl', 'name': 'Mateusz Uszyński'},
#      'message': 'Add dependencies and permission',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/m-uszynski/mySong/commits/3300dd8918fa54202768018a012cf5f831fed517'},
#     {'sha': '543c3f1e7fc218b5015daff7a6f0d3afb4bb8c43',
#      'author': {'email': 'rtck@o2.pl', 'name': 'Mateusz Uszyński'},
#      'message': 'Add Song class',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/m-uszynski/mySong/commits/543c3f1e7fc218b5015daff7a6f0d3afb4bb8c43'},
#     {'sha': 'a62810fa8568b322253a9f8f5c60c62162ba464f',
#      'author': {'email': 'rtck@o2.pl', 'name': 'Mateusz Uszyński'},
#      'message': 'Add RetrofitInstance class',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/m-uszynski/mySong/commits/a62810fa8568b322253a9f8f5c60c62162ba464f'},
#     {'sha': '4ea03530dcaa42f9c3d02165831c86ca67936d31',
#      'author': {'email': 'rtck@o2.pl', 'name': 'Mateusz Uszyński'},
#      'message': 'Add SongService Interface',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/m-uszynski/mySong/commits/4ea03530dcaa42f9c3d02165831c86ca67936d31'},
#     {'sha': '39355b6d7f469ddd9c93d00262c636a22d9360d4',
#      'author': {'email': 'rtck@o2.pl', 'name': 'Mateusz Uszyński'},
#      'message': 'Add display songs from external API',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/m-uszynski/mySong/commits/39355b6d7f469ddd9c93d00262c636a22d9360d4'},
#     {'sha': 'fe1b94f20c9aa2647f82e0eaff980710c65976cf',
#      'author': {'email': 'rtck@o2.pl', 'name': 'Mateusz Uszyński'},
#      'message': 'Add added song',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/m-uszynski/mySong/commits/fe1b94f20c9aa2647f82e0eaff980710c65976cf'},
#     {'sha': 'abba256295ab188fb52e807c26beb0dcd93bdde9',
#      'author': {'email': 'rtck@o2.pl', 'name': 'Mateusz Uszyński'},
#      'message': 'Add search songs',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/m-uszynski/mySong/commits/abba256295ab188fb52e807c26beb0dcd93bdde9'},
#     {'sha': 'eb830e2d97e9499673926fd2c17b1f5889c30323',
#      'author': {'email': 'rtck@o2.pl', 'name': 'Mateusz Uszyński'},
#      'message': 'Fix AddEditActivity Layout',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/m-uszynski/mySong/commits/eb830e2d97e9499673926fd2c17b1f5889c30323'},
#     {'sha': '0422903be8a3190cea7037bca85bde22e6356a0e',
#      'author': {'email': 'rtck@o2.pl', 'name': 'Mateusz Uszyński'},
#      'message': 'Add edit songs feature',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/m-uszynski/mySong/commits/0422903be8a3190cea7037bca85bde22e6356a0e'},
#     {'sha': '18a7d85e6ecf2c15420a15a3f896ee81d6d58faf',
#      'author': {'email': 'rtck@o2.pl', 'name': 'Mateusz Uszyński'},
#      'message': 'Add display song details feature',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/m-uszynski/mySong/commits/18a7d85e6ecf2c15420a15a3f896ee81d6d58faf'},
#     {'sha': 'b94af6272400df93f4f7fe108c25535762244b2c',
#      'author': {'email': 'rtck@o2.pl', 'name': 'Mateusz Uszyński'},
#      'message': 'Add delete song feature',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/m-uszynski/mySong/commits/b94af6272400df93f4f7fe108c25535762244b2c'},
#     {'sha': 'ccdaf8eb5ce2d534e3e5439a419b264d24ef6916',
#      'author': {'email': 'rtck@o2.pl', 'name': 'Mateusz Uszyński'},
#      'message': 'Add thumbnail from YouTube to MainActivity for all songs',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/m-uszynski/mySong/commits/ccdaf8eb5ce2d534e3e5439a419b264d24ef6916'},
#     {'sha': '9136275d4d6168942fe199c0265066f80f60ce9a',
#      'author': {'email': 'rtck@o2.pl', 'name': 'Mateusz Uszyński'},
#      'message': 'Edit DetailsActivity view',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/m-uszynski/mySong/commits/9136275d4d6168942fe199c0265066f80f60ce9a'},
#     {'sha': '90a3ecb77230e32323b67c970bcd6f873e0cc247',
#      'author': {'email': 'rtck@o2.pl', 'name': 'Mateusz Uszyński'},
#      'message': 'Edit MainActivity',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/m-uszynski/mySong/commits/90a3ecb77230e32323b67c970bcd6f873e0cc247'},
#     {'sha': 'efca3b91051b3e7c26a55a8f0e783fda4ef0a69d',
#      'author': {'email': 'rtck@o2.pl', 'name': 'Mateusz Uszyński'},
#      'message': 'Add youtube intent future and Add implementation to shake feature',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/m-uszynski/mySong/commits/efca3b91051b3e7c26a55a8f0e783fda4ef0a69d'},
#     {'sha': 'cc270a5fed0a8343a3e0daf1afaad23b85e13549',
#      'author': {'email': 'rtck@o2.pl', 'name': 'Mateusz Uszyński'},
#      'message': 'Add random song after shaking, Edit Main View',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/m-uszynski/mySong/commits/cc270a5fed0a8343a3e0daf1afaad23b85e13549'},
#     {'sha': 'd0a0c8f4549bc34dc1b84f7cf148da1a868f47f2',
#      'author': {'email': 'rtck@o2.pl', 'name': 'Mateusz Uszyński'},
#      'message': 'Move all const value to xml files',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/m-uszynski/mySong/commits/d0a0c8f4549bc34dc1b84f7cf148da1a868f47f2'},
#     {'sha': 'a4fdb363962174a2ee9d49623f611c1719c75e9f',
#      'author': {'email': '35667247+m-uszynski@users.noreply.github.com',
#       'name': 'Mateusz Uszyński'},
#      'message': 'Merge pull request #1 from m-uszynski/displayApi\n\nDisplay api',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/m-uszynski/mySong/commits/a4fdb363962174a2ee9d49623f611c1719c75e9f'}]},
#   'public': True,
#   'created_at': '2019-12-19T00:34:00Z'},
#  {'id': '11121573879',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 114471457,
#    'name': 'Lombiq/Arithmetics',
#    'url': 'https://api.github.com/repos/Lombiq/Arithmetics'},
#   'payload': {'push_id': 4414641373,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/issue/HAST-132',
#    'head': 'b4dd23def5490c868100544da65bef62ad4a9df0',
#    'before': 'b4dd23def5490c868100544da65bef62ad4a9df0',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-12-19T00:34:00Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '11121573880',
#   'type': 'PushEvent',
#   'actor': {'id': 59035814,
#    'login': 'jhennifer14',
#    'display_login': 'jhennifer14',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jhennifer14',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59035814?'},
#   'repo': {'id': 228944518,
#    'name': 'jhennifer14/PSTeam',
#    'url': 'https://api.github.com/repos/jhennifer14/PSTeam'},
#   'payload': {'push_id': 4414641376,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/patch-1',
#    'head': '58318ab36ab91034dd3f1948b27df2107e9a74e4',
#    'before': 'a607032ad6642a9852d4b0da6db4ab4907a72725',
#    'commits': [{'sha': '58318ab36ab91034dd3f1948b27df2107e9a74e4',
#      'author': {'email': '59035814+jhennifer14@users.noreply.github.com',
#       'name': 'jhennifer14'},
#      'message': 'Update PSAntiban.txt',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jhennifer14/PSTeam/commits/58318ab36ab91034dd3f1948b27df2107e9a74e4'}]},
#   'public': True,
#   'created_at': '2019-12-19T00:34:00Z'},
#  {'id': '11121573872',
#   'type': 'PushEvent',
#   'actor': {'id': 14055146,
#    'login': 'shirakaba',
#    'display_login': 'shirakaba',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shirakaba',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14055146?'},
#   'repo': {'id': 227920326,
#    'name': 'shirakaba/rns-browser',
#    'url': 'https://api.github.com/repos/shirakaba/rns-browser'},
#   'payload': {'push_id': 4414641369,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/retract-bars-on-scroll',
#    'head': 'ee54fb3941b66286454d2c0bb1ecd413b96f81c7',
#    'before': '20a0012671910f974568dae1ce51a026b9bb883f',
#    'commits': [{'sha': 'ee54fb3941b66286454d2c0bb1ecd413b96f81c7',
#      'author': {'email': '14055146+shirakaba@users.noreply.github.com',
#       'name': 'Jamie Birch'},
#      'message': 'node-sass 4.13',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shirakaba/rns-browser/commits/ee54fb3941b66286454d2c0bb1ecd413b96f81c7'}]},
#   'public': True,
#   'created_at': '2019-12-19T00:34:00Z'},
#  {'id': '11121573875',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 59260831,
#    'name': 'zomeki/zomeki3',
#    'url': 'https://api.github.com/repos/zomeki/zomeki3'},
#   'payload': {'ref': 'dependabot/bundler/rack-2.0.8',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-19T00:34:00Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
r = requests.get('https://cat-fact.herokuapp.com/facts')
r.text
# Out:
# '{"all":[{"_id":"58e008b80aac31001185ed0d","text":"Adult cats only meow to communicate with humans.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":7,"userUpvoted":null},{"_id":"58e009650aac31001185ed13","text":"In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":6,"userUpvoted":null},{"_id":"58e00b2b0aac31001185ed1f","text":"A cat has five toes on his front paws, and four on the back, unless he\'s a polydactyl.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"58e00be30aac31001185edfe","text":"Cats use their whiskers to detect if they can fit through a space.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"58e00b4d0aac31001185ed22","text":"Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"599f89639a11040c4a163440","text":"Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"5b199196ce456e001424256a","text":"Cats can distinguish different flavors in water.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"5b1b411d841d9700146158d9","text":"The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"5b4912c60508220014ccfe99","text":"Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"58e007db0aac31001185ecf7","text":"There are cats who have survived falls from over 32 stories (320 meters) onto concrete.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":3,"userUpvoted":null},{"_id":"58e008800aac31001185ed07","text":"Wikipedia has a recording of a cat meowing, because why not?","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":3,"userUpvoted":null},{"_id":"58e009790aac31001185ed14","text":"The technical term for \\"hairball\\" is \\"bezoar.\\"","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":3,"userUpvoted":null},{"_id":"58e00a120aac31001185ed17","text":"A cat\'s brain is 90% similar to a human\'s — more similar than to a dog\'s.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":3,"userUpvoted":null},{"_id":"591d9b2f227c1a0020d26823","text":"Every year, nearly four million cats are eaten in China as a delicacy.","type":"cat","user":{"_id":"587288f6e6f85e64ae1c7ef7","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":3,"userUpvoted":null},{"_id":"5974fb4dfedacb0020b5b4cc","text":"Cats can survive falls from up to 65 feet or more.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":3,"userUpvoted":null},{"_id":"59a60ba66acf530020f35873","text":"Most cats don\'t lik ...
